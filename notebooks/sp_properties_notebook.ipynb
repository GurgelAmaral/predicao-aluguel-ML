# %%
import pandas as pd

# %%
df = pd.read_csv('sao-paulo-properties-april-2019.csv')

# %%
df
# Out:
#         Price  Condo  Size  Rooms  Toilets  Suites  Parking  Elevator  \
# 0         930    220    47      2        2       1        1         0
# 1        1000    148    45      2        2       1        1         0
# 2        1000    100    48      2        2       1        1         0
# 3        1000    200    48      2        2       1        1         0
# 4        1300    410    55      2        2       1        1         1
# ...       ...    ...   ...    ...      ...     ...      ...       ...
# 13635  265000    420    51      2        1       0        1         0
# 13636  545000    630    74      3        2       1        2         0
# 13637  515000   1100   114      3        3       1        1         0
# 13638  345000     48    39      1        2       1        1         0
# 13639  161987      0    44      2        1       0        1         0
#
#        Furnished  Swimming Pool  New                 District  \
# 0              0              0    0    Artur Alvim/São Paulo
# ...

# %% [markdown]
# Análise dos NaNs do dataset

# %%
df.isna().any()
# Out:
# Price               False
# Condo               False
# Size                False
# Rooms               False
# Toilets             False
# Suites              False
# Parking             False
# Elevator            False
# Furnished           False
# Swimming Pool       False
# New                 False
# District            False
# Negotiation Type    False
# Property Type       False
# Latitude            False
# Longitude           False
# dtype: bool

# %% [markdown]
# Análise dos tipos de dados do cada coluna

# %%
df.dtypes
# Out:
# Price                 int64
# Condo                 int64
# Size                  int64
# Rooms                 int64
# Toilets               int64
# Suites                int64
# Parking               int64
# Elevator              int64
# Furnished             int64
# Swimming Pool         int64
# New                   int64
# District             object
# Negotiation Type     object
# Property Type        object
# Latitude            float64
# Longitude           float64
# dtype: object
